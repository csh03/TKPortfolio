# %%
import pandas as pd
from pandas import Series,DataFrame

# %%
stock_features = pd.read_csv('ticker_list.csv',sep=',')
stock_features
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $133.77
# 1        AA                    Alcoa Corporation Common Stock     $47.85
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.87
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.86
# 4      AACI            Armada Acquisition Corp. I Common Stock     $9.91
# ...     ...                                                ...       ...
# 8347    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $28.89
# 8348     ZY                         Zymergen Inc. Common Stock     $2.61
# 8349   ZYME                       Zymeworks Inc. Common Shares     $6.61
# 8350   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $1.18
# 8351   ZYXI                            Zynex Inc. Common Stock     $8.65
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# ...

# %%
result = stock_features['Symbol']

# %%
result.to_csv("ticker_list.csv",index=False)
